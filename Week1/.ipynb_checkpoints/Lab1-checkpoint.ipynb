# %% [markdown]
# ---
# title: "Lab 1"
# author: "Ben Kessler"
# output: html
# self-contained: true
# toc: true
# theme: cosmo
# echo: true
# ---

# %% [markdown]
# Task 1
# 1. The variables being used in this bubble plot are income on the x-axis and life-expectancy on the y-axis. The size and color aesthetics of each bubble are related to the geographic area where the data is related to. For example, countries in Africa are blue with while countries in North and South America are light green.

# %%
# 2
import pandas as pd
data_1 = pd.read_csv("/Users/ben/Documents/GitHub/DSML/Data/q1data.csv")
data_1
# Out:
#       income  life_exp  ...       eight_regions           world_bank_region
# 0     1910.0      61.0  ...           asia_west                  South Asia
# 1    11100.0      78.1  ...         europe_east       Europe & Central Asia
# 2    11100.0      74.7  ...        africa_north  Middle East & North Africa
# 3    46900.0      81.9  ...         europe_west       Europe & Central Asia
# 4     7680.0      60.8  ...  africa_sub_saharan          Sub-Saharan Africa
# ..       ...       ...  ...                 ...                         ...
# 192  20400.0      75.4  ...       america_south   Latin America & Caribbean
# 193   5350.0      73.3  ...   east_asia_pacific         East Asia & Pacific
# 194   4700.0      67.8  ...           asia_west  Middle East & North Africa
# 195   3200.0      57.5  ...  africa_sub_saharan          Sub-Saharan Africa
# 196   2560.0      54.4  ...  africa_sub_saharan          Sub-Saharan Africa
#
# [197 rows x 9 columns]

# %%
data_1["population"] = data_1["population"].astype(float)
data_1["income"] = np.log2(data_1["income"])

# %%
# 3 (Need to figure out how to space the axis marks correctly)
#| warning: false
import numpy as np
from plotnine import ggplot, aes, geom_point, labs, scale_x_continuous, scale_y_continuous, theme, element_text, scale_size_radius
(ggplot(data_1, aes(x = "income", y = "life_exp", fill = "four_regions")) + 
    geom_point(aes(size = "population", na_rm = True)) +
    scale_size_radius(range = (2, 30)) +
    scale_x_continuous(breaks = [9, 10, 11, 12, 13, 14, 15, 16, 17], labels = [0, 500, 1000, 2000, 4000, 8000, 16000, 32000, 64000]) +
    scale_y_continuous(limits = [15, 90], breaks = [20, 30, 40, 50, 60, 70, 80, 90]) +
    labs(
        x = "Income [GDP/Capita]",
        y = "",
        subtitle = "Life Expectancy [Years]"
    ) +
    theme(
        axis_text_x = element_text(angle=45),
        figure_size = (14, 8)
    )
)
# Out:
# /Users/ben/anaconda3/lib/python3.11/site-packages/plotnine/layer.py:364: PlotnineWarning: geom_point : Removed 4 rows containing missing values.
# <Figure Size: (1400 x 800)>

# %% [markdown]
# Task 2
# 1.
