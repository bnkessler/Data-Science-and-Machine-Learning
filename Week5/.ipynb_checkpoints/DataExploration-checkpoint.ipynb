# %%
import pandas as pd
import numpy as np
import re

# %%
data = pd.read_csv("/Users/ben/Documents/GitHub/DSML/Data/national_park_trails.csv")
data
# Out:
#       trail_id                                               name  \
# 0     10020048                            Harding Ice Field Trail
# 1     10236086                         Mount Healy Overlook Trail
# 2     10267857                                 Exit Glacier Trail
# 3     10236076                               Horseshoe Lake Trail
# 4     10236082                                 Triple Lakes Trail
# ...        ...                                                ...
# 3308  10008302               Silversword Loop Via Halemau'u Trail
# 3309  10236001                                Keonehe'ehe'e Trail
# 3310  10258707                     Red Hill Overlook Summit Trail
# 3311  10014989                                        Kaupo Trail
# 3312  10259465  Ka Lu'u o ka O'o Cinder Cone via Crater and Sl...
#
#                        area_name             city_name state_name  \
# 0     Kenai Fjords National Park                Seward     Alaska
# ...

# %%
data.loc[data["length"] == data["length"].max()]
# Out:
#       trail_id                          name              area_name city_name  \
# 2753  10040050  Olympic Peninsula Loop Drive  Olympic National Park   Olympia
#
#       state_name   country_name                               _geoloc  \
# 2753  Washington  United States  {'lat': 47.02164, 'lng': -122.90689}
#
#       popularity      length  elevation_gain  difficulty_rating route_type  \
# 2753      9.9486  529794.728       5096.8656                  1       loop
#
#       visitor_usage  avg_rating  num_reviews  \
# 2753            2.0         4.5           18
#
#                                                features  \
# 2753  ['beach', 'forest', 'lake', 'kids', 'hot-sprin...
#
#                                              activities units no_dogs
# 2753  ['birding', 'camping', 'fishing', 'nature-trip...     i      []

# %%
data.value_counts("city_name")
data.value_counts("country_name")
data.value_counts("route_type")
# Out:
# route_type
# out and back      1906
# loop              1087
# point to point     320
# dtype: int64

# %%
california_trails = data[data["state_name"] == "California"]
yosemite_trails = california_trails[california_trails["area_name"] == "Yosemite National Park"]
yosemite_trails[["name", "state_name", "area_name", "num_reviews", "popularity"]].sort_values("num_reviews", ascending=False)[0:10]
# Out:
#                                            name  state_name  \
# 219  Vernal and Nevada Falls via the Mist Trail  California
# 220                  Upper Yosemite Falls Trail  California
# 221                             Half Dome Trail  California
# 228                                Vernal Falls  California
# 223                  Lower Yosemite Falls Trail  California
# 225                             Four Mile Trail  California
# 224           Clouds Rest Trail via Tenaya Lake  California
# 230           Mirror Lake via Valley Loop Trail  California
# 226                         Sentinel Dome Trail  California
# 237                       Bridalveil Fall Trail  California
#
#                   area_name  num_reviews  popularity
# 219  Yosemite National Park         1869     68.1488
# 220  Yosemite National Park         1351     53.6280
# 221  Yosemite National Park         1196     52.5316
# 228  Yosemite National Park         1107     37.2129
# ...

# %%
data.value_counts("state_name")
# Out:
# state_name
# California        707
# Washington        320
# Wyoming           311
# Utah              292
# Colorado          262
# Virginia          191
# Maine             179
# Tennessee         175
# Arizona           174
# Montana           151
# North Carolina    118
# Texas              94
# Ohio               50
# Hawaii             35
# Florida            31
# Alaska             29
# Kentucky           28
# Nevada             25
# North Dakota       23
# Oregon             22
# South Dakota       20
# Indiana            16
# Arkansas           16
# Maui               14
# New Mexico          8
# South Carolina      8
# Minnesota           7
# Michigan            4
# Missouri            2
# Georgia             1
# dtype: int64

# %%
data[["trail_id", "name", "state_name", "popularity"]].loc[data["popularity"] > 25].sort_values("popularity", ascending = False)
# Out:
#       trail_id                                             name  state_name  \
# 2150  10006571                             Angels Landing Trail        Utah
# 926   10026705                               Emerald Lake Trail    Colorado
# 219   10026910       Vernal and Nevada Falls via the Mist Trail  California
# 927   10235688                 Sky Pond via Glacier Gorge Trail    Colorado
# 2151  10012464                              Delicate Arch Trail        Utah
# ...        ...                                              ...         ...
# 2175  10033026  Mossy Cave Turret Arch and Little Windows Trail        Utah
# 1463  10012004                               Cracker Lake Trail     Montana
# 949   10035508                                    Cascade Falls    Colorado
# 1890  10259229                         Spruce Flats Falls Trail   Tennessee
# 246   10013977      Condor Gulch Trail to High Peaks Trail Loop  California
#
#       popularity
# 2150     84.6229
# 926      83.0341
# ...

# %%
data.value_counts("route_type")
# Out:
# route_type
# out and back      1906
# loop              1087
# point to point     320
# dtype: int64

# %%
data["no_dogs"] = data["features"].apply(lambda x: re.findall(pattern = "dogs-no", string = x))
count = 0
for row in data["no_dogs"]:
    count += len(row)
print(count)
# Out:
# 2423
